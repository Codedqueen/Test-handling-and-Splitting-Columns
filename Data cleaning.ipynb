# %% [markdown]
# # Data cleaning in python

# %% [markdown]
# ### Common issues with data
# #### .Loading or reloading errors
# #### .Reading the file
# #### .Inconsistent column name
# #### .Missing data
# #### .Different data types
# #### .Duplicate rows etc:

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Loading or Reading the Files

# %% [markdown]
# ### .Encoding error
# ### .Inconsistent rows

# %%
#issue 1
df = pd.read_csv("C:\\Users\\user\\Downloads\\Unclean+data+set+for+Data+Cleaning+Lesson.csv")

# %%
df
# Out:
#                                      movie_title  num_critic_for_reviews  \
# 0                                       Avatar?�                     723
# 1     Pirates of the Caribbean: At World's End?�                     302
# 2                                      Spectre?�                     602
# 3                        The Dark Knight Rises?�                     813
# 4                                  John Carter?�                     462
# 5                                 Spider-Man 3?�                     392
# 6                                      Tangled?�                     324
# 7                      Avengers: Age of Ultron?�                     635
# 8                      Avengers: Age of Ultron?�                     635
# 9       Harry Potter and the Half-Blood Prince?�                     375
# 10          Batman v Superman: Dawn of Justice?�                     673
# 11                            Superman Returns?�                     434
# ...

# %%
#solution 1
#UTF encoding
df1= pd.read_csv("C:\\Users\\user\\Downloads\\Unclean+data+set+for+Data+Cleaning+Lesson.csv",encoding='latin')

# %%
df1.head()
# Out:
#                                     movie_title  num_critic_for_reviews  \
# 0                                    Avatar?ï¿½                     723
# 1  Pirates of the Caribbean: At World's End?ï¿½                     302
# 2                                   Spectre?ï¿½                     602
# 3                     The Dark Knight Rises?ï¿½                     813
# 4                               John Carter?ï¿½                     462
#
#    duration DIRECTOR_facebook_likes  actor_3_facebook_likes  \
# 0     178.0                      10                     855
# 1       NaN                     563                    1000
# 2     148.0                      20                     161
# 3       NaN                   22000                   23000
# 4     132.0                   "475"                     530
#
#    ACTOR_1_facebook_likes      gross  num_voted_users  \
# 0                    1000  760505847         886204.0
# 1                   40000  309404152         471220.0
# ...

# %% [markdown]
# #### Solution 2
# ##### Use text Editor and save as utf-8, ISO 8859-1,latin1

# %%
df= pd.read_csv("C:\\Users\\user\\Downloads\\Unclean+data+set+for+Data+Cleaning+Lesson.csv",encoding='latin')

# %%
df.head()
# Out:
#                                     movie_title  num_critic_for_reviews  \
# 0                                    Avatar?ï¿½                     723
# 1  Pirates of the Caribbean: At World's End?ï¿½                     302
# 2                                   Spectre?ï¿½                     602
# 3                     The Dark Knight Rises?ï¿½                     813
# 4                               John Carter?ï¿½                     462
#
#    duration DIRECTOR_facebook_likes  actor_3_facebook_likes  \
# 0     178.0                      10                     855
# 1       NaN                     563                    1000
# 2     148.0                      20                     161
# 3       NaN                   22000                   23000
# 4     132.0                   "475"                     530
#
#    ACTOR_1_facebook_likes      gross  num_voted_users  \
# 0                    1000  760505847         886204.0
# 1                   40000  309404152         471220.0
# ...

# %% [markdown]
# # Inconsistent column names

# %% [markdown]
# #### .change cases
# #### .Rename them

# %% [markdown]
# # Change the case to upper

# %%
df.columns
# Out:
# Index(['movie_title', 'num_critic_for_reviews', 'duration',
#        'DIRECTOR_facebook_likes', 'actor_3_facebook_likes',
#        'ACTOR_1_facebook_likes', 'gross', 'num_voted_users',
#        'Cast_Total_facebook_likes', 'facenumber_in_poster',
#        'num_user_for_reviews', 'budget', 'title_year',
#        'ACTOR_2_facebook_likes', 'imdb_score', 'title_year.1'],
#       dtype='object')

# %%
df
# Out:
#                                        movie_title  num_critic_for_reviews  \
# 0                                       Avatar?ï¿½                     723
# 1     Pirates of the Caribbean: At World's End?ï¿½                     302
# 2                                      Spectre?ï¿½                     602
# 3                        The Dark Knight Rises?ï¿½                     813
# 4                                  John Carter?ï¿½                     462
# 5                                 Spider-Man 3?ï¿½                     392
# 6                                      Tangled?ï¿½                     324
# 7                      Avengers: Age of Ultron?ï¿½                     635
# 8                      Avengers: Age of Ultron?ï¿½                     635
# 9       Harry Potter and the Half-Blood Prince?ï¿½                     375
# 10          Batman v Superman: Dawn of Justice?ï¿½                     673
# ...

# %%
df.columns.str.upper()
# Out:
# Index(['MOVIE_TITLE', 'NUM_CRITIC_FOR_REVIEWS', 'DURATION',
#        'DIRECTOR_FACEBOOK_LIKES', 'ACTOR_3_FACEBOOK_LIKES',
#        'ACTOR_1_FACEBOOK_LIKES', 'GROSS', 'NUM_VOTED_USERS',
#        'CAST_TOTAL_FACEBOOK_LIKES', 'FACENUMBER_IN_POSTER',
#        'NUM_USER_FOR_REVIEWS', 'BUDGET', 'TITLE_YEAR',
#        'ACTOR_2_FACEBOOK_LIKES', 'IMDB_SCORE', 'TITLE_YEAR.1'],
#       dtype='object')

# %%
df.columns = df.columns.str.upper()

# %%
#it now changes everything to capital

# %%
df.columns
# Out:
# Index(['MOVIE_TITLE', 'NUM_CRITIC_FOR_REVIEWS', 'DURATION',
#        'DIRECTOR_FACEBOOK_LIKES', 'ACTOR_3_FACEBOOK_LIKES',
#        'ACTOR_1_FACEBOOK_LIKES', 'GROSS', 'NUM_VOTED_USERS',
#        'CAST_TOTAL_FACEBOOK_LIKES', 'FACENUMBER_IN_POSTER',
#        'NUM_USER_FOR_REVIEWS', 'BUDGET', 'TITLE_YEAR',
#        'ACTOR_2_FACEBOOK_LIKES', 'IMDB_SCORE', 'TITLE_YEAR.1'],
#       dtype='object')

# %% [markdown]
# # Renaming columns

# %% [markdown]
# #### .Adding a default value for missing data or use mean to fill it
# #### .Delete the row/column with missing data
# #### .Interpolate the rows
# #### .Replace

# %%
df.rename(columns= {'DURATION': 'TIME'})
# Out:
#                                        MOVIE_TITLE  NUM_CRITIC_FOR_REVIEWS  \
# 0                                       Avatar?ï¿½                     723
# 1     Pirates of the Caribbean: At World's End?ï¿½                     302
# 2                                      Spectre?ï¿½                     602
# 3                        The Dark Knight Rises?ï¿½                     813
# 4                                  John Carter?ï¿½                     462
# 5                                 Spider-Man 3?ï¿½                     392
# 6                                      Tangled?ï¿½                     324
# 7                      Avengers: Age of Ultron?ï¿½                     635
# 8                      Avengers: Age of Ultron?ï¿½                     635
# 9       Harry Potter and the Half-Blood Prince?ï¿½                     375
# 10          Batman v Superman: Dawn of Justice?ï¿½                     673
# ...

# %% [markdown]
# # Missing Data

# %% [markdown]
# ### To check missing Data

# %% [markdown]
# ### False means no missing Data .True means there is no data

# %% [markdown]
# ### . df.isnull().sum()int
# ### . df.snull().any()boot

# %%
#check for the mising data using isnul
df.isnull()
# Out:
#     MOVIE_TITLE  NUM_CRITIC_FOR_REVIEWS  DURATION  DIRECTOR_FACEBOOK_LIKES  \
# 0         False                   False     False                    False
# 1         False                   False      True                    False
# 2         False                   False     False                    False
# 3         False                   False      True                    False
# 4         False                   False     False                    False
# 5         False                   False     False                    False
# 6         False                   False      True                    False
# 7         False                   False     False                    False
# 8         False                   False     False                    False
# 9         False                   False     False                    False
# 10        False                   False     False                     True
# ...

# %%
df.isnull().any() #this steamlines it to the exact data you want
# Out:
# MOVIE_TITLE                  False
# NUM_CRITIC_FOR_REVIEWS       False
# DURATION                      True
# DIRECTOR_FACEBOOK_LIKES       True
# ACTOR_3_FACEBOOK_LIKES       False
# ACTOR_1_FACEBOOK_LIKES       False
# GROSS                        False
# NUM_VOTED_USERS               True
# CAST_TOTAL_FACEBOOK_LIKES     True
# FACENUMBER_IN_POSTER          True
# NUM_USER_FOR_REVIEWS         False
# BUDGET                       False
# TITLE_YEAR                   False
# ACTOR_2_FACEBOOK_LIKES        True
# IMDB_SCORE                   False
# TITLE_YEAR.1                  True
# dtype: bool

# %% [markdown]
# ##### columns with na using true or false
# ##### false means it doesn't have a NaN

# %%
df.isnull().any().any()
# Out:
# True

# %% [markdown]
# ##### column with NaN using integers

# %%
df.isnull().any().any()  #this shows the entire dataFrame
# Out:
# True

# %% [markdown]
# ##### Total number of missing NA

# %%
df.isnull().sum()   #checking the missing NA
# Out:
# MOVIE_TITLE                  0
# NUM_CRITIC_FOR_REVIEWS       0
# DURATION                     3
# DIRECTOR_FACEBOOK_LIKES      2
# ACTOR_3_FACEBOOK_LIKES       0
# ACTOR_1_FACEBOOK_LIKES       0
# GROSS                        0
# NUM_VOTED_USERS              1
# CAST_TOTAL_FACEBOOK_LIKES    2
# FACENUMBER_IN_POSTER         5
# NUM_USER_FOR_REVIEWS         0
# BUDGET                       0
# TITLE_YEAR                   0
# ACTOR_2_FACEBOOK_LIKES       1
# IMDB_SCORE                   0
# TITLE_YEAR.1                 7
# dtype: int64

# %%
df.isnull().sum().sum()  #checking the total sum of missing Na
# Out:
# 21

# %% [markdown]
# ### Adding a default value of putting the missing data

# %%
df.head()
# Out:
#                                     MOVIE_TITLE  NUM_CRITIC_FOR_REVIEWS  \
# 0                                    Avatar?ï¿½                     723
# 1  Pirates of the Caribbean: At World's End?ï¿½                     302
# 2                                   Spectre?ï¿½                     602
# 3                     The Dark Knight Rises?ï¿½                     813
# 4                               John Carter?ï¿½                     462
#
#    DURATION DIRECTOR_FACEBOOK_LIKES  ACTOR_3_FACEBOOK_LIKES  \
# 0     178.0                      10                     855
# 1       NaN                     563                    1000
# 2     148.0                      20                     161
# 3       NaN                   22000                   23000
# 4     132.0                   "475"                     530
#
#    ACTOR_1_FACEBOOK_LIKES      GROSS  NUM_VOTED_USERS  \
# 0                    1000  760505847         886204.0
# 1                   40000  309404152         471220.0
# ...

# %% [markdown]
# ###### You can decide to replace the Na with zero, but check to be sure that zero is not part of the Dataset

# %%
df_with_0 = df.fillna(0)

# %%
df_with_0.head()
# Out:
#                                     MOVIE_TITLE  NUM_CRITIC_FOR_REVIEWS  \
# 0                                    Avatar?ï¿½                     723
# 1  Pirates of the Caribbean: At World's End?ï¿½                     302
# 2                                   Spectre?ï¿½                     602
# 3                     The Dark Knight Rises?ï¿½                     813
# 4                               John Carter?ï¿½                     462
#
#    DURATION DIRECTOR_FACEBOOK_LIKES  ACTOR_3_FACEBOOK_LIKES  \
# 0     178.0                      10                     855
# 1       0.0                     563                    1000
# 2     148.0                      20                     161
# 3       0.0                   22000                   23000
# 4     132.0                   "475"                     530
#
#    ACTOR_1_FACEBOOK_LIKES      GROSS  NUM_VOTED_USERS  \
# 0                    1000  760505847         886204.0
# 1                   40000  309404152         471220.0
# ...

# %%
#fill it with mean
df['DURATION']
# Out:
# 0     178.0
# 1       NaN
# 2     148.0
# 3       NaN
# 4     132.0
# 5     156.0
# 6       NaN
# 7     141.0
# 8     141.0
# 9     153.0
# 10    183.0
# 11    169.0
# 12    106.0
# 13    151.0
# Name: DURATION, dtype: float64

# %%
df['DURATION'].mean()
# Out:
# 150.72727272727272

# %%
df_with_mean = df.DURATION.fillna(df['DURATION'].mean())

# %%
df_with_mean
# Out:
# 0     178.000000
# 1     150.727273
# 2     148.000000
# 3     150.727273
# 4     132.000000
# 5     156.000000
# 6     150.727273
# 7     141.000000
# 8     141.000000
# 9     153.000000
# 10    183.000000
# 11    169.000000
# 12    106.000000
# 13    151.000000
# Name: DURATION, dtype: float64

# %% [markdown]
# ###### Drop NA

# %%
df.head()
# Out:
#                                     MOVIE_TITLE  NUM_CRITIC_FOR_REVIEWS  \
# 0                                    Avatar?ï¿½                     723
# 1  Pirates of the Caribbean: At World's End?ï¿½                     302
# 2                                   Spectre?ï¿½                     602
# 3                     The Dark Knight Rises?ï¿½                     813
# 4                               John Carter?ï¿½                     462
#
#    DURATION DIRECTOR_FACEBOOK_LIKES  ACTOR_3_FACEBOOK_LIKES  \
# 0     178.0                      10                     855
# 1       NaN                     563                    1000
# 2     148.0                      20                     161
# 3       NaN                   22000                   23000
# 4     132.0                   "475"                     530
#
#    ACTOR_1_FACEBOOK_LIKES      GROSS  NUM_VOTED_USERS  \
# 0                    1000  760505847         886204.0
# 1                   40000  309404152         471220.0
# ...

# %%
df.isnull().sum().sum()
# Out:
# 21

# %%
df.shape
# Out:
# (14, 16)

# %%
df_drop = df.dropna()   #use this so that you dont change the entire dataset.
                         #usedf.dropna() when you want to change the entire dataset

# %%
df_drop
# Out:
#                                        MOVIE_TITLE  NUM_CRITIC_FOR_REVIEWS  \
# 2                                      Spectre?ï¿½                     602
# 8                      Avengers: Age of Ultron?ï¿½                     635
# 12                           Quantum of Solace?ï¿½                     403
# 13  Pirates of the Caribbean: Dead Man's Chest?ï¿½                     313
#
#     DURATION DIRECTOR_FACEBOOK_LIKES  ACTOR_3_FACEBOOK_LIKES  \
# 2      148.0                      20                     161
# 8      141.0                      10                   19000
# 12     106.0                     395                     393
# 13     151.0                     563                    1000
#
#     ACTOR_1_FACEBOOK_LIKES      GROSS  NUM_VOTED_USERS  \
# 2                    11000  200074175         275868.0
# 8                    26000  458991599         462669.0
# 12                     451  168368427         330784.0
# 13                   40000  423032628         522040.0
#
# ...

# %%
df_drop.shape
# Out:
# (4, 16)

# %% [markdown]
# ##### If we observe this has reduced the dataset drastically.In such cases we need to use a conditional statement

# %%
df_with_condition = df.dropna(thresh=2)

# %%
# ?df.dropna
# Out:
# Signature:
# df.dropna(
#     axis: 'Axis' = 0,
#     how: 'str' = 'any',
#     thresh=None,
#     subset=None,
#     inplace: 'bool' = False,
# )
# Docstring:
# Remove missing values.
#
# See the :ref:`User Guide <missing_data>` for more on which values are
# considered missing, and how to work with missing data.
#
# Parameters
# ----------
# axis : {0 or 'index', 1 or 'columns'}, default 0
#     Determine if rows or columns which contain missing values are
#     removed.
#
#     * 0, or 'index' : Drop rows which contain missing values.
#     * 1, or 'columns' : Drop columns which contain missing value.
#
#     .. versionchanged:: 1.0.0
#
#        Pass tuple or list to drop on multiple axes.
#        Only a single axis is allowed.
#
# how : {'any', 'all'}, default 'any'
#     Determine if row or column is removed from DataFrame, when we have
#     at least one NA or all NA.
#
#     * 'any' : If any NA values are present, drop that row or column.
# ...

# %% [markdown]
# ##### We can se that our date still remains the same , we can use Thresh or how=any to achieve this. using Thresh you can give a condition if it is having more than two Na drop it. you can also do a combination of how=any and Thresh (How='any',thresh=1) or use 'thresh=1',it will still give same result.

# %%
df_drop_With_condition = df.dropna(thresh=1)

# %%
df_drop_With_condition.shape
# Out:
# (14, 16)

# %%
df.shape
# Out:
# (14, 16)

# %%
df_drop_With_condition = df.dropna(thresh=2)

# %%
df_drop_With_condition.shape
# Out:
# (14, 16)

# %%
df.shape
# Out:
# (14, 16)

# %%
df_drop_With_condition = df.dropna(How='any',thresh=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13604/1848349933.py in <module>
# ----> 1 df_drop_With_condition = df.dropna(How='any',thresh=1)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# TypeError: dropna() got an unexpected keyword argument 'How'

# %%
df_drop_With_condition.shape
# Out:
# (14, 16)

# %%
df_drop_column = df.dropna(axis=1)

# %%
df_drop_column.shape
# Out:
# (14, 9)
